# %%
import pandas as pd
import matplotlib as pyplot

# %%
# Importing the csv file into pandas
df = pd.read_csv('coffee_shop_data.csv')
df
# Out:
#     OrderID        Date Region            Store Category       Product  \
# 0      1001  2026-05-01   East  Providence Cafe   Coffee         Latte
# 1      1002  2026-05-01   East  Providence Cafe     Food        Muffin
# 2      1003  2026-05-01   West  Seattle Central   Coffee     Cold Brew
# 3      1004  2026-05-02  South     Austin Beans      Tea    Chai Latte
# 4      1005  2026-05-02   West  Seattle Central     Food         Bagel
# 5      1006  2026-05-02   East  Providence Cafe   Coffee    Cappuccino
# 6      1007  2026-05-03  South     Austin Beans   Coffee     Americano
# 7      1008  2026-05-03   West  Seattle Central      Tea     Green Tea
# 8      1009  2026-05-03   East  Providence Cafe     Food     Croissant
# 9      1010  2026-05-04  South     Austin Beans     Food        Cookie
# 10     1011  2026-05-04   West  Seattle Central   Coffee         Mocha
# 11     1012  2026-05-04   East  Providence Cafe      Tea  Matcha Latte
# ...

# %%
df.shape
rows,cols = df.shape
print("Rows:",rows)
print("Columns:",cols)
# Out:
# Rows: 15
# Columns: 10

# %%
df.describe()
# Out:
#            OrderID  UnitsSold     Revenue        Cost  DiscountPercent
# count    15.000000  15.000000   15.000000   15.000000        15.000000
# mean   1008.000000  37.200000  159.000000   71.533333         4.333333
# std       4.472136  15.469786   64.005301   36.935981         6.510065
# min    1001.000000  18.000000   81.000000   30.000000         0.000000
# 25%    1004.500000  26.000000  107.500000   41.000000         0.000000
# 50%    1008.000000  33.000000  140.000000   56.000000         0.000000
# 75%    1011.500000  47.500000  209.500000   93.000000         7.500000
# max    1015.000000  70.000000  286.000000  140.000000        20.000000

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'Region', 'Store', 'Category', 'Product',
#        'UnitsSold', 'Revenue', 'Cost', 'DiscountPercent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OrderID              int64
# Date                object
# Region              object
# Store               object
# Category            object
# Product             object
# UnitsSold            int64
# Revenue            float64
# Cost               float64
# DiscountPercent      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          15 non-null     int64
#  1   Date             15 non-null     object
#  2   Region           15 non-null     object
#  3   Store            15 non-null     object
#  4   Category         15 non-null     object
#  5   Product          15 non-null     object
#  6   UnitsSold        15 non-null     int64
#  7   Revenue          15 non-null     float64
#  8   Cost             15 non-null     float64
#  9   DiscountPercent  15 non-null     int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 1.3+ KB

# %%
df.head(5)
# Out:
#    OrderID        Date Region            Store Category     Product  \
# 0     1001  2026-05-01   East  Providence Cafe   Coffee       Latte
# 1     1002  2026-05-01   East  Providence Cafe     Food      Muffin
# 2     1003  2026-05-01   West  Seattle Central   Coffee   Cold Brew
# 3     1004  2026-05-02  South     Austin Beans      Tea  Chai Latte
# 4     1005  2026-05-02   West  Seattle Central     Food       Bagel
#
#    UnitsSold  Revenue   Cost  DiscountPercent
# 0         45    247.5  135.0                0
# 1         30    105.0   42.0               10
# 2         52    286.0  140.0                5
# 3         28    126.0   56.0                0
# 4         40    140.0   52.0               15

# %%
df.isnull().sum()
# Out:
# OrderID            0
# Date               0
# Region             0
# Store              0
# Category           0
# Product            0
# UnitsSold          0
# Revenue            0
# Cost               0
# DiscountPercent    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Which store performs the best
df.groupby('Store')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Store
# Providence Cafe    914.5
# Seattle Central    799.5
# Austin Beans       671.0
# Name: Revenue, dtype: float64

# %%
# Which product categories are the most profitable
df.groupby('Category')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Category
# Coffee    1522.5
# Food       539.0
# Tea        323.5
# Name: Revenue, dtype: float64

# %%
# Whether discounts are negatively affecting profits
